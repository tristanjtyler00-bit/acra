# %% [markdown]
# ##### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import sys

sys.path.append("..")
from acra import procedure_to_xdl
logging.basicConfig(level=logging.ERROR)

# %% [markdown]
# ##### Translate

# %% [markdown]
# Make sure to set your OpenAI API key according to the README.md before running

# %%
procedure = """PROCEDURE HERE"""

EXPERIMENT_ID = "translation_1"
CONTINUATION = False # if True, no initial XDL-database is provided/ or was created previously
GRAPH_TEMPLATE = None # if you have a custom graph to be used for simulation of the exectuion
ASK_AMBIGUOUS = False # whether to include 'expert knowledge' by asking
EXPAND_MEMORY = True # store succesfull translations for subsequent translations

# %%
procedure_to_xdl(
    procedure,
    trial_dir=EXPERIMENT_ID,
    continuation=CONTINUATION,
    graph=GRAPH_TEMPLATE,
    ask_ambiguous=ASK_AMBIGUOUS,
)
